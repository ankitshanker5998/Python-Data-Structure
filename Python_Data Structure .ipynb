# %% [markdown]
#                               Assignment - Python - data structure
#
# #  1 . What are data structures , and why are they important?
#  It is the way of organizing and storing data so that it can be accessed and manipulated efficiently .
# It is important to organize data easily ,we can modify and store the data in sequence so that it  can easily be accessed and modified and . it is in the form of  list,arrays etc.
# Efficiently data handling and faster program execution
#
# # 2 .Explain the difference between mutable and immutable data types with examples .
# Mutable data types whose vaules can be changed , modify , add new elements . It is  created without creating a new object
# Examples –  list,dict,sets
# Immutable data types whose values can’t changed after creation .if we required any modification need a new object.
#
# # 3.What are the main differences between lists and tuples in Python?
# Lists are mutable .Elements can be added  , removed , modified . Performance is slow . In list using a [] sign . Uses more memory
# Tuples are immutable , Elements are not possible to add , modify or remove . It's slightly faster as compared to lists . competition of small memories . Uses parenthesis().
#
# # 4. Describe how dictionaries store data.
# Which stores the data in the form of key value pair. In dictionary we can access using the key  not  through indexing procedure.
#
# # 5.Why might you use a set instead of a list in Python?
# Because sets are un- ordered collection of unique items and perform a fast accessing. It is easily add some elements . there is no concepts of  indexing.
#
# # 6. What is a string in Python, and how is it different from a list?
# A string  is a sequence of a character . It represents and manipulates textual data .Characters are represented by using numerical values . Each character is assigned a unique value so that a computer machine can understand a text. Using ( ‘ ’) (“ ”) .
#             String  are mutable , list are immutable .String are using a text related methods upper and lower case . list are using a data   handling methods like  append, remove .
#
# # 7.How do tuples ensure data integrity in Python?
# Tuples are immutable . Once tuple is created . it cannot be changes , added or remove
#
# # 8.What is a hash table, and how does it relate to dictionaries in Python?
# A hash table is a data structure that stores data in key  value pairs and allows very fast access to values.
#             It is related - each key in a dictionary ia hashed .In dictionary only key value paired are stored
#
# # 9.Can lists contain different data types in Python?
# Yes
#
# # 10 Explain why strings are immutable in Python
# String are immutable because once the string are created it cannot be changed.
#
# # 11. what advantages do dictionaries offer over lists for certain tasks ?
# ADVANTEGES--
# Fast look up by keys
# clear key values  relationships
# no need for fixed positions
# easy to update and  modify
# prevents duplicate  keys
#
# # 12 Describe a scenario where using a tuple would be preferable over a list.
#  A tuple is preferred over a list when you want to store a collection of values that should not change after  creation .
#
# A scenario of aadhar card ,  atm pin , employee id . we cant change . we can ue tuple  t o store the data .
#
# # 13.How do sets handle duplicate values in Python?
# A set  stores only unique elements .
#  We are adding , it will ignore
#  No error it  raised .
#
# # 14 How doe the "in" keyword  work differently for list and dictionaries?
# for "in" when we used in the list the . we are checking a values available in the form a elements.
# for "in whe we use in the dictionaries only key pairs elements are available not a values .
#
# # 15.Can you modify the elements of a tuple? Explain why or why not.
# No tuples are immutable once it is created . it can not be changed, added or removed.
#
#
# # 16 What is a nested dictionary, and give an example of its use case.
# A nested dictionary is a dictionary that contain one or more dictionaries as its value . it is  a dictionary inside another dictionary used t o represent structural and hierarchical data .
#             Use cases – students data . employee  data etc
#
# # 17 Describe the time  complexity and accesing elements in a dictionary?
#
#
# # 18 In what situations are lists preferred over dictionaries?
# Lists are preferred over  when you need ordered , index based or simple  collection of data .
#
# # 19  What are dictionaries considered unordered , and how does that affect data retrieval?
# Dictionaries are considered as  a unordered because they stores the data in the form of  hashing , not in a position .
# keys are placed in memory based on the hashing values.
# This affects a  data retrieval by accessing by key pairs not a position .
# iteration order is not indexing
# no index based operation
# fast and predictable look up
#
# # 20 Explain the difference between a list and a dictionary in terms of data retrieval.
#        List- access method is indexing
#                 Speed - slow for large lists
#                 Allows duplicate elements
#         Dictionary - access method by key
#                            Very  fast by using a hash table
#                             Keys must be unique

# %%
# 1. Write a code to create a string with your name and proint it  
name = " Ankit"
print(name)
# Out:
#  Ankit

# %%
# 2. Write a code to find the length of the string "Hello World".
s = "Hello World"
len(s)
# Out:
# 11

# %%
# 3. Write a code to slice the first 3 characters from the string "Python Programming"
str1 = "Python Programming"
str1[0:3]
# Out:
# 'Pyt'

# %%
#4. Write a code to convert the string "hello" to uppercase. 
text = "hello"
text.upper()
# Out:
# 'HELLO'

# %%
#5 . Write a code to replace the word "apple" with "orange" in the string "I like apple".
str2 = " I like apple"
str2.replace("apple","orange")
# Out:
# ' I like orange'

# %%
#6 . Write a code to create a list with numbers 1 to 5 and print it.
my_list = [1,2 ,3,4,5]
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
#7 . Write a code to append the number 10 to the list [1, 2, 3, 4].
a = [1, 2, 3, 4]
a.append(10)
print(a)
# Out:
# [1, 2, 3, 4, 10]

# %%
# 8 .Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].
c =  [1, 2, 3, 4, 5]
c.remove(3)
print(c)
# Out:
# [1, 2, 4, 5]

# %%
# 9.Write a code to access the second element in the list ['a', 'b', 'c', 'd'].

my_list = ['a', 'b', 'c', 'd']
my_list[1]
# Out:
# 'b'

# %%
# 10 .Write a code to reverse the list [10, 20, 30, 40, 50]
my_list = [10, 20, 30, 40, 50]
my_list.reverse()
print("Reversed list:", my_list)
# Out:
# Reversed list: [50, 40, 30, 20, 10]

# %%
#11. Write a co9de to create  a tuple with  the elements 100,200,300 and print it 
points = ( 100,200,300)
print(points)
# Out:
# (100, 200, 300)

# %%
#12. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').
my_tuple = ('red', 'green', 'blue', 'yellow')
my_tuple[-2]
# Out:
# 'blue'

# %%
# 13 . Write a code to find the minimum number in the tuple (10, 20, 5, 15).
num = (10, 20, 5, 15)
minimum = min(num)
print(minimum)
# Out:
# 5

# %%
#14 . Write a code to find the index of the element 'cat' in the tuple ('dog', 'cat', 'rabbit').
s = ('dog', 'cat', 'rabbit')
s[1]
# Out:
# 'cat'

# %%
#15 . Write a code to create a tuple containing three different fruits and check if 'kiwi' is in it.

fruits = ("apple","banana","kiwi")
if "kiwi" in fruits:
    print("kiwi is available in fruits list")
else:
    print("kiwi is not available in fruits list")
# Out:
# kiwi is available in fruits list

# %%
# 16 Write a code to create a set with the elements 'a', 'b', 'c' and print it.
set = { 'a', 'b', 'c' }
print(set)
# Out:
# {'b', 'a', 'c'}

# %%
#17 .Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
s = {1, 2, 3, 4, 5}
s.clear()
print(s)
# Out:
# set()

# %%
# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.
s={1, 2, 3, 4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
# 19 Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}
a = {1, 2, 3}
b = {3, 4, 5}
print(a|b)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 20 Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}
a = {1, 2, 3}
b = {3, 4, 5}
print(a&b)
# Out:
# {3}

# %%
# 21 Write a code to create a dictionary with the keys "name", "age", and "city", and print it
d = {"name", "age","city"}
print(d)
# Out:
# {'name', 'age', 'city'}

# %%
#22. Write a code to add a new key-value pair "country": "USA" to the dictionary {name: "John", age: 25}
x = {"name": "John", "age": 25}
x["country"] = "USA"
print(d)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
# 23 Write a code to access the value associated with the key "name" in the dictionary {name: "Alice", age: 30}.
d = {"name": "Alice", "age": 30}
print(d["name"])
# Out:
# Alice

# %%
# 24 Write a code to remove the key "age" from the dictionary {name: "Bob", age: 22, city: "New York"}
d = {"name": "Bob", "age": 22, "city": "New York"}
del d["age"]
print(d)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
# 25 Write a code to check if the key "city" exists in the dictionary {name: "Alice", city: "Paris"}.
d = {"name": "Alice", "city": "Paris"}
print("city" in d )
# Out:
# True

# %%
# 26 Write a code to create a list, a tuple, and a dictionary, and print them all.
a = [ 1,2,3]
b = {4,5,6}
d = {"a": 1, "b": 2}
print(a)
print(b)
print(d)
# Out:
# [1, 2, 3]
# {4, 5, 6}
# {'a': 1, 'b': 2}

# %%
# 27 Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.

# %%
# 28 Write a code to create a list with strings and print the element at the third index.
a = ["apple", "banana", "cherry", "date"]
print(a[3])
# Out:
# date

# %%
# 29 Write a code to combine two dictionaries into one and print the result.
a = {"a": 1, "b": 2}
b = {"c": 3, "d": 4}
combined = a|b
print(combined)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# 30 Write a code to convert a list of strings into a set.
lst = ["apple", "banana", "apple", "cherry"]
s = set(lst)
print(s)
# Out:
# {'banana', 'apple', 'cherry'}
